# %% [markdown]
# # Bayesian Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "bayesian_model_card",
        "prior_review",
        "likelihood_review",
        "inference_diagnostics",
        "calibration_audit",
        "decision_threshold_review",
        "uncertainty_communication_plan"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "complete",
        "planned",
        "in_review",
        "planned"
    ],
    "owner": [
        "Model Governance",
        "Domain Expert",
        "Model Validation",
        "Data Science",
        "Risk",
        "Governance",
        "UX Research"
    ]
})

register

# %% [markdown]
# # Reproducibility Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "dataset_manifest",
        "code_version",
        "environment_file",
        "random_seed_record",
        "validation_report",
        "reproducibility_review"
    ],
    "status": [
        "complete",
        "complete",
        "complete",
        "complete",
        "in_review",
        "planned"
    ],
    "owner": [
        "Data Steward",
        "Research Software",
        "Research Software",
        "Modeling Team",
        "Scientific Reviewer",
        "Governance"
    ]
})

register

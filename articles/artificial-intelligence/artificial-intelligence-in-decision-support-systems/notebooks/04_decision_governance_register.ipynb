# %% [markdown]
# # Decision Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "decision_question",
        "utility_function",
        "threshold_record",
        "human_review_policy",
        "override_log",
        "scenario_review"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "complete",
        "active",
        "planned"
    ],
    "owner": [
        "Decision Owner",
        "Analytics",
        "Governance",
        "Operations",
        "Operations",
        "Risk Review"
    ]
})

register

# %% [markdown]
# # Environmental AI Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "governance_artifact": [
        "sensor_inventory",
        "remote_sensing_product_record",
        "model_validation_report",
        "uncertainty_review",
        "environmental_justice_review",
        "alert_escalation_protocol"
    ],
    "status": [
        "complete",
        "complete",
        "in_review",
        "planned",
        "in_review",
        "complete"
    ],
    "owner": [
        "Monitoring Team",
        "Earth Observation Team",
        "ML Validation",
        "Science Review",
        "Public Accountability",
        "Emergency Response"
    ]
})

register

# %% [markdown]
# # Foundation Model Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "foundation_model_card",
        "pretraining_data_record",
        "objective_review",
        "evaluation_report",
        "privacy_review",
        "bias_review",
        "deployment_approval"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "in_review",
        "planned",
        "planned",
        "pending"
    ],
    "owner": [
        "Model Governance",
        "Data Steward",
        "Research",
        "Evaluation",
        "Privacy",
        "Responsible AI",
        "Governance"
    ]
})

register

# %% [markdown]
# # Learning AI Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "education_ai_system_card",
        "ai_use_policy",
        "assessment_redesign",
        "privacy_review",
        "accessibility_review",
        "bias_equity_review",
        "incident_response",
        "deployment_readiness"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "planned",
        "in_review",
        "planned",
        "complete",
        "planned"
    ],
    "owner": [
        "Academic Technology",
        "Faculty Governance",
        "Instructional Design",
        "Privacy Office",
        "Accessibility Office",
        "Equity Review",
        "Student Support",
        "Governance"
    ]
})

register

# %% [markdown]
# # Uncertainty Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "calibration_review",
        "uncertainty_system_card",
        "threshold_policy",
        "abstention_review",
        "human_review_escalation",
        "recalibration_review",
        "monitoring_readiness"
    ],
    "status": [
        "complete",
        "complete",
        "in_review",
        "planned",
        "in_review",
        "planned",
        "complete"
    ],
    "owner": [
        "Model Governance",
        "ML Engineering",
        "Risk",
        "Operations",
        "Human Review Team",
        "ML Engineering",
        "MLOps"
    ]
})

register

# %% [markdown]
# # Multimodal Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "multimodal_system_card",
        "modality_source_review",
        "fusion_review",
        "action_safety_review",
        "privacy_review",
        "accessibility_review",
        "incident_response_plan"
    ],
    "status": [
        "complete",
        "in_review",
        "in_review",
        "planned",
        "complete",
        "planned",
        "complete"
    ],
    "owner": [
        "Model Governance",
        "Data Stewardship",
        "ML Engineering",
        "Safety",
        "Privacy",
        "Accessibility",
        "Operations"
    ]
})

register

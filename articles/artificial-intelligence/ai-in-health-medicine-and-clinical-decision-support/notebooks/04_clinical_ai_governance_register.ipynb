# %% [markdown]
# # Clinical AI Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "clinical_ai_system_card",
        "intended_use_review",
        "validation_review",
        "bias_equity_review",
        "privacy_security_review",
        "change_control",
        "incident_response",
        "deployment_readiness"
    ],
    "status": [
        "complete",
        "complete",
        "in_review",
        "in_review",
        "planned",
        "planned",
        "complete",
        "planned"
    ],
    "owner": [
        "Clinical Governance",
        "Clinical Owner",
        "Biostatistics",
        "Equity Review",
        "Privacy Office",
        "Model Governance",
        "Patient Safety",
        "Governance"
    ]
})

register

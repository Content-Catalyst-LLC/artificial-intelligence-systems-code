# %% [markdown]
# # Synthetic Content Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "prompt_hash",
        "model_version",
        "output_hash",
        "content_credentials",
        "human_review_record",
        "publication_decision"
    ],
    "status": [
        "complete",
        "complete",
        "complete",
        "in_review",
        "complete",
        "planned"
    ],
    "owner": [
        "AI Operations",
        "Model Governance",
        "Content Operations",
        "Provenance Lead",
        "Editorial Review",
        "Publisher"
    ]
})

register

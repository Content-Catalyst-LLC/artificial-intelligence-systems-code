# %% [markdown]
# # Planning Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "planning_system_card",
        "action_registry_review",
        "reward_review",
        "policy_evaluation",
        "human_approval_gate",
        "rollback_readiness",
        "incident_response",
        "deployment_readiness"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "planned",
        "complete",
        "planned",
        "in_review",
        "planned"
    ],
    "owner": [
        "Model Governance",
        "Security",
        "Risk",
        "ML Engineering",
        "Operations",
        "Platform",
        "Incident Response",
        "Governance"
    ]
})

register

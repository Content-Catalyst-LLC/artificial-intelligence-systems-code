# %% [markdown]
# # Explainability Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "model_card",
        "explanation_method_record",
        "counterfactual_audit",
        "stability_report",
        "contestation_process"
    ],
    "status": [
        "complete",
        "complete",
        "in_review",
        "complete",
        "planned"
    ],
    "owner": [
        "Model Governance",
        "ML Engineering",
        "Risk Review",
        "AI Safety",
        "Policy"
    ]
})

register

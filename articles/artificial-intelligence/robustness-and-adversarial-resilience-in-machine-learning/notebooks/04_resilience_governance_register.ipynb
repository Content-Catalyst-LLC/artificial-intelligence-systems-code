# %% [markdown]
# # Resilience Governance Register

# %%
import pandas as pd

register = pd.DataFrame({
    "artifact": [
        "threat_model",
        "red_team_review",
        "robustness_evaluation",
        "data_poisoning_review",
        "prompt_injection_incident_plan",
        "resilience_controls",
        "deployment_readiness"
    ],
    "status": [
        "complete",
        "in_review",
        "complete",
        "planned",
        "complete",
        "in_review",
        "planned"
    ],
    "owner": [
        "Security",
        "Red Team",
        "ML Engineering",
        "Data Governance",
        "Operations",
        "Model Governance",
        "Governance"
    ]
})

register
